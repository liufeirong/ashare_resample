# %%
import numpy as np
import pandas as pd

import time
import datetime
import threading
import redis

import talib
import tushare as ts
from utils.time_util import get_market_date
from utils.stat_util import get_stat_info

red = redis.Redis(host='localhost')

# %%
def resample_1min(df_buffer, date_time, df_last_1min):
    df_freq = None
    data_list = []
    for ticker, group in df_buffer.groupby(['code']):
        group = group.set_index(['datetime']).astype(float)
        Open = group['price'].iloc[0]
        Close = group['price'].iloc[-1]
        High = group['price'].max()
        Low =  group['price'].min()
        Vol = group['volume'].iloc[-1]
        Amount = group['amount'].iloc[-1]
        data_list.append([ticker,date_time,Open,High,Low,Close,Vol,Amount,Vol,Amount])
    df_1min = pd.DataFrame(data_list,columns=['code','datetime','open','high','close','low','vol','amount','vol_sum','amount_sum'])
    
    if df_last_1min is not None:
        df_1min['vol'] = df_1min['vol_sum'] - df_last_1min['vol_sum']
        df_1min['amount'] = df_1min['amount_sum'] - df_last_1min['amount_sum']
    return df_1min

# %%
def run_resample_1min():
    resample_time = '09:30:00'
    cur_date = datetime.datetime.now().strftime('%Y-%m-%d')
    key_1min = 't_1min_' + cur_date
    df_1min, df_last_1min = None, None
    df_bytes_1min = red.get(key_1min)
    if df_bytes_1min is not None:
        df_1min = pd.read_msgpack(df_bytes_1min)
        last_datetime = df_1min['datetime'].iloc[-1].strftime('%Y-%m-%d %H:%M:%S')   
        df_last_1min = df_1min.loc[df_1min['datetime']==last_datetime]
        resample_time = last_datetime[-8:]
        
    while resample_time < '15:00:00':
        t_tick_keys = map(lambda r:str(r, encoding='utf-8'), red.keys('t_tick_'+cur_date+'*:*'))
        t_tick_keys = sorted(filter(lambda r: r[-8:]>resample_time, t_tick_keys))
        if len(t_tick_keys) == 0 and datetime.datetime.now().strftime('%H-%M-%S')>'15:00:00':
            print('the market has closed!')
            break
        df_cur_1min = None
        for key_tick in t_tick_keys:
            df_bytes_tick = red.get(key_tick)
            df_buffer = pd.read_msgpack(df_bytes_tick)
            df_cur_1min = resample_1min(df_buffer, pd.to_datetime(key_tick[7:]), df_last_1min)
            if df_1min is None:
                df_1min = df_cur_1min
            else:
                df_1min = pd.concat([df_1min, df_cur_1min])
            df_bytes_1min = df_1min.to_msgpack()
            red.set(key_1min, df_bytes_1min)
            print(key_tick + '  has resample into table ' + key_1min + '!')
            df_last_1min = df_cur_1min
            resample_time = key_tick[-8:]
        time.sleep(50)

# %%
run_resample_1min()
# Out:
# /Users/harry/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: The read_msgpack is deprecated and will be removed in a future version.
# It is recommended to use pyarrow for on-the-wire transmission of pandas objects.
#   """Entry point for launching an IPython kernel.
# /Users/harry/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:28: FutureWarning: to_msgpack is deprecated and will be removed in a future version.
# It is recommended to use pyarrow for on-the-wire transmission of pandas objects.
# t_tick_2020-03-03 11:30:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:00:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:01:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:02:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:03:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:04:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:05:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:06:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:07:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:08:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:09:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:10:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:11:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:12:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:13:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:14:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:15:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:16:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:17:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:18:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:19:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:20:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:21:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:22:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:23:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:24:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:25:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:26:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:27:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:28:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:29:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:30:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:31:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:32:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:33:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:34:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:35:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:36:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:37:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:38:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:39:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:40:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:41:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:42:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:43:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:44:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:45:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:46:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:47:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:48:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:49:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:50:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:51:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:52:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:53:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:54:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:55:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:56:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:57:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:58:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 13:59:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:00:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:01:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:02:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:03:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:04:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:05:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:06:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:07:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:08:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:09:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:10:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:11:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:12:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:13:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:14:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:15:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:16:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:17:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:18:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:19:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:20:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:21:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:22:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:23:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:24:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:25:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:26:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:27:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:28:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:29:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:30:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:31:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:32:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:33:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:34:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:35:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:36:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:37:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:38:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:39:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:40:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:41:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:42:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:43:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:44:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:45:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:46:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:47:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:48:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:49:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:50:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:51:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:52:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:53:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:54:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:55:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:56:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:57:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:58:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 14:59:00  has resample into table t_1min_2020-03-03!
# t_tick_2020-03-03 15:00:00  has resample into table t_1min_2020-03-03!
